# %%
#Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
import os
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import shuffle
# Out:
# 2024-03-20 19:30:45.633608: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-20 19:30:45.715256: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-20 19:30:45.737410: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-20 19:30:46.166227: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/include:/usr/lib/cuda/lib64::/home/senthilkmp/miniconda3/envs/tf/lib/
# 2024-03-20 19:30:46.166282: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/include:/usr/lib/cuda/lib64::/home/senthilkmp/miniconda3/envs/tf/lib/
# 2024-03-20 19:30:46.166287: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# Settting the path to dataset
data_dir = 'DataSet'

# %%
# Get the list of all image files in the directory
all_image_files = [os.path.join(data_dir, class_folder, filename) for class_folder in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, class_folder)) for filename in os.listdir(os.path.join(data_dir, class_folder)) if filename.endswith(".jpg")]

# Create labels based on folder names or any other logic suitable for your dataset
all_image_labels = [os.path.basename(os.path.dirname(filepath)) for filepath in all_image_files]

# Map string labels to integer labels
label_mapping = {label: str(idx) for idx, label in enumerate(set(all_image_labels))}
all_image_labels = [label_mapping[label] for label in all_image_labels]

# Create a DataFrame to store file paths and labels
df = pd.DataFrame({'filepath': all_image_files, 'label': all_image_labels})

# Split the data into training and testing sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
# Create data generators for training and testing
img_size = (150, 150)
batch_size = 64

train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(dataframe=train_df, x_col='filepath', y_col='label', target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_generator = test_datagen.flow_from_dataframe(dataframe=test_df, x_col='filepath', y_col='label', target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=False)
# Out:
# Found 5148 validated image filenames belonging to 3 classes.
# Found 1288 validated image filenames belonging to 3 classes.

# %%
import matplotlib.pyplot as plt
train_dir = 'DataSet'

# Count the number of images in each class folder
class_counts = {}
for class_folder in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_folder)
    if os.path.isdir(class_path):
        num_images = len(os.listdir(class_path))
        class_counts[class_folder] = num_images

# Plot the number of images in each class
plt.figure(figsize=(10, 6))
plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Number of Images in Each Class')
plt.xticks(rotation=45)
plt.show()

# %%
# Build the CNN(VGG) model
model = models.Sequential()
model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
# Out:
# 2024-03-20 19:30:47.429189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.435080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.435213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.435632: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-20 19:30:47.435995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.436098: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.436185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.784301: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.784456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.784593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-20 19:30:47.784662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9844 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath='model.h5', save_best_only=True, monitor='val_accuracy', mode='max', verbose=1),  # Model checkpoint
]

# %%
# Visualize the model
import visualkeras
from PIL import ImageFont  
visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=888x826>

# %%
# Train the model
history = model.fit(
    train_generator,
    workers=12,
    validation_data = test_generator, 
    epochs = 50,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 2024-03-20 19:30:53.783362: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2024-03-20 19:30:55.954483: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 81/81 [==============================] - ETA: 0s - loss: 0.6505 - accuracy: 0.6748
# Epoch 1: val_accuracy improved from -inf to 0.83618, saving model to model.h5
# 81/81 [==============================] - 67s 495ms/step - loss: 0.6505 - accuracy: 0.6748 - val_loss: 0.4678 - val_accuracy: 0.8362
# Epoch 2/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3698 - accuracy: 0.8539
# Epoch 2: val_accuracy did not improve from 0.83618
# 81/81 [==============================] - 33s 352ms/step - loss: 0.3698 - accuracy: 0.8539 - val_loss: 0.5456 - val_accuracy: 0.7585
# Epoch 3/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3612 - accuracy: 0.8611
# Epoch 3: val_accuracy improved from 0.83618 to 0.90217, saving model to model.h5
# 81/81 [==============================] - 31s 355ms/step - loss: 0.3612 - accuracy: 0.8611 - val_loss: 0.2965 - val_accuracy: 0.9022
# Epoch 4/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.8974
# Epoch 4: val_accuracy improved from 0.90217 to 0.92935, saving model to model.h5
# 81/81 [==============================] - 33s 375ms/step - loss: 0.2734 - accuracy: 0.8974 - val_loss: 0.1890 - val_accuracy: 0.9293
# Epoch 5/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9320
# Epoch 5: val_accuracy improved from 0.92935 to 0.93634, saving model to model.h5
# 81/81 [==============================] - 33s 362ms/step - loss: 0.1733 - accuracy: 0.9320 - val_loss: 0.1676 - val_accuracy: 0.9363
# Epoch 6/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9390
# Epoch 6: val_accuracy improved from 0.93634 to 0.94410, saving model to model.h5
# 81/81 [==============================] - 33s 367ms/step - loss: 0.1544 - accuracy: 0.9390 - val_loss: 0.1700 - val_accuracy: 0.9441
# Epoch 7/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9431
# Epoch 7: val_accuracy did not improve from 0.94410
# 81/81 [==============================] - 34s 380ms/step - loss: 0.1465 - accuracy: 0.9431 - val_loss: 0.1640 - val_accuracy: 0.9418
# Epoch 8/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9474
# Epoch 8: val_accuracy did not improve from 0.94410
# 81/81 [==============================] - 32s 358ms/step - loss: 0.1373 - accuracy: 0.9474 - val_loss: 0.1661 - val_accuracy: 0.9379
# Epoch 9/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9516
# Epoch 9: val_accuracy did not improve from 0.94410
# 81/81 [==============================] - 32s 365ms/step - loss: 0.1261 - accuracy: 0.9516 - val_loss: 0.1642 - val_accuracy: 0.9410
# Epoch 10/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9476
# Epoch 10: val_accuracy improved from 0.94410 to 0.94565, saving model to model.h5
# 81/81 [==============================] - 33s 368ms/step - loss: 0.1325 - accuracy: 0.9476 - val_loss: 0.1440 - val_accuracy: 0.9457
# Epoch 11/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9549
# Epoch 11: val_accuracy did not improve from 0.94565
# 81/81 [==============================] - 32s 356ms/step - loss: 0.1191 - accuracy: 0.9549 - val_loss: 0.1736 - val_accuracy: 0.9433
# Epoch 12/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9491
# Epoch 12: val_accuracy improved from 0.94565 to 0.95342, saving model to model.h5
# 81/81 [==============================] - 32s 360ms/step - loss: 0.1315 - accuracy: 0.9491 - val_loss: 0.1455 - val_accuracy: 0.9534
# Epoch 13/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9586
# Epoch 13: val_accuracy did not improve from 0.95342
# 81/81 [==============================] - 31s 354ms/step - loss: 0.1070 - accuracy: 0.9586 - val_loss: 0.2011 - val_accuracy: 0.9363
# Epoch 14/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9577
# Epoch 14: val_accuracy improved from 0.95342 to 0.95652, saving model to model.h5
# 81/81 [==============================] - 32s 360ms/step - loss: 0.1096 - accuracy: 0.9577 - val_loss: 0.1334 - val_accuracy: 0.9565
# Epoch 15/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9592
# Epoch 15: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 36s 372ms/step - loss: 0.1023 - accuracy: 0.9592 - val_loss: 0.1646 - val_accuracy: 0.9565
# Epoch 16/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9643
# Epoch 16: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 33s 376ms/step - loss: 0.0965 - accuracy: 0.9643 - val_loss: 0.1860 - val_accuracy: 0.9503
# Epoch 17/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9645
# Epoch 17: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 31s 348ms/step - loss: 0.0987 - accuracy: 0.9645 - val_loss: 0.1664 - val_accuracy: 0.9472
# Epoch 18/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9713
# Epoch 18: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 32s 356ms/step - loss: 0.0765 - accuracy: 0.9713 - val_loss: 0.1594 - val_accuracy: 0.9511
# Epoch 19/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9679
# Epoch 19: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 32s 355ms/step - loss: 0.0786 - accuracy: 0.9679 - val_loss: 0.1785 - val_accuracy: 0.9464
# Epoch 20/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9681
# Epoch 20: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 32s 363ms/step - loss: 0.0824 - accuracy: 0.9681 - val_loss: 0.1674 - val_accuracy: 0.9534
# Epoch 21/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9660
# Epoch 21: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 33s 364ms/step - loss: 0.0851 - accuracy: 0.9660 - val_loss: 0.2217 - val_accuracy: 0.9262
# Epoch 22/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9623
# Epoch 22: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 32s 363ms/step - loss: 0.0961 - accuracy: 0.9623 - val_loss: 0.1625 - val_accuracy: 0.9472
# Epoch 23/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9679
# Epoch 23: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 33s 369ms/step - loss: 0.0896 - accuracy: 0.9679 - val_loss: 0.1841 - val_accuracy: 0.9565
# Epoch 24/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9664
# Epoch 24: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 32s 359ms/step - loss: 0.0846 - accuracy: 0.9664 - val_loss: 0.1353 - val_accuracy: 0.9542
# Epoch 25/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9724
# Epoch 25: val_accuracy did not improve from 0.95652
# 81/81 [==============================] - 31s 368ms/step - loss: 0.0774 - accuracy: 0.9724 - val_loss: 0.1402 - val_accuracy: 0.9550
# Epoch 26/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9765
# Epoch 26: val_accuracy improved from 0.95652 to 0.95807, saving model to model.h5
# 81/81 [==============================] - 30s 339ms/step - loss: 0.0549 - accuracy: 0.9765 - val_loss: 0.1374 - val_accuracy: 0.9581
# Epoch 27/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9707
# Epoch 27: val_accuracy did not improve from 0.95807
# 81/81 [==============================] - 30s 341ms/step - loss: 0.0761 - accuracy: 0.9707 - val_loss: 0.1653 - val_accuracy: 0.9542
# Epoch 28/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9759
# Epoch 28: val_accuracy did not improve from 0.95807
# 81/81 [==============================] - 32s 354ms/step - loss: 0.0597 - accuracy: 0.9759 - val_loss: 0.1393 - val_accuracy: 0.9573
# Epoch 29/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9780
# Epoch 29: val_accuracy did not improve from 0.95807
# 81/81 [==============================] - 34s 389ms/step - loss: 0.0542 - accuracy: 0.9780 - val_loss: 0.1410 - val_accuracy: 0.9565
# Epoch 30/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9777
# Epoch 30: val_accuracy did not improve from 0.95807
# 81/81 [==============================] - 34s 381ms/step - loss: 0.0602 - accuracy: 0.9777 - val_loss: 0.1566 - val_accuracy: 0.9550
# Epoch 31/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9744
# Epoch 31: val_accuracy did not improve from 0.95807
# 81/81 [==============================] - 33s 364ms/step - loss: 0.0672 - accuracy: 0.9744 - val_loss: 0.1375 - val_accuracy: 0.9550
# Epoch 32/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9833
# Epoch 32: val_accuracy did not improve from 0.95807
# 81/81 [==============================] - 33s 372ms/step - loss: 0.0441 - accuracy: 0.9833 - val_loss: 0.1885 - val_accuracy: 0.9503
# Epoch 33/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9800
# Epoch 33: val_accuracy improved from 0.95807 to 0.95963, saving model to model.h5
# 81/81 [==============================] - 33s 362ms/step - loss: 0.0525 - accuracy: 0.9800 - val_loss: 0.1580 - val_accuracy: 0.9596
# Epoch 34/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9806
# Epoch 34: val_accuracy did not improve from 0.95963
# 81/81 [==============================] - 32s 364ms/step - loss: 0.0573 - accuracy: 0.9806 - val_loss: 0.1579 - val_accuracy: 0.9519
# Epoch 35/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9868
# Epoch 35: val_accuracy did not improve from 0.95963
# 81/81 [==============================] - 33s 366ms/step - loss: 0.0390 - accuracy: 0.9868 - val_loss: 0.1702 - val_accuracy: 0.9581
# Epoch 36/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9891
# Epoch 36: val_accuracy did not improve from 0.95963
# 81/81 [==============================] - 33s 376ms/step - loss: 0.0275 - accuracy: 0.9891 - val_loss: 0.1984 - val_accuracy: 0.9425
# Epoch 37/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9796
# Epoch 37: val_accuracy did not improve from 0.95963
# 81/81 [==============================] - 33s 367ms/step - loss: 0.0559 - accuracy: 0.9796 - val_loss: 0.1479 - val_accuracy: 0.9589
# Epoch 38/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9854
# Epoch 38: val_accuracy improved from 0.95963 to 0.96273, saving model to model.h5
# 81/81 [==============================] - 32s 361ms/step - loss: 0.0393 - accuracy: 0.9854 - val_loss: 0.1655 - val_accuracy: 0.9627
# Epoch 39/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9911
# Epoch 39: val_accuracy improved from 0.96273 to 0.96506, saving model to model.h5
# 81/81 [==============================] - 31s 340ms/step - loss: 0.0233 - accuracy: 0.9911 - val_loss: 0.1678 - val_accuracy: 0.9651
# Epoch 40/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9806
# Epoch 40: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 30s 342ms/step - loss: 0.0535 - accuracy: 0.9806 - val_loss: 0.1718 - val_accuracy: 0.9596
# Epoch 41/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9833
# Epoch 41: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 30s 339ms/step - loss: 0.0468 - accuracy: 0.9833 - val_loss: 0.1916 - val_accuracy: 0.9410
# Epoch 42/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9759
# Epoch 42: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 30s 341ms/step - loss: 0.0673 - accuracy: 0.9759 - val_loss: 0.2107 - val_accuracy: 0.9519
# Epoch 43/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9862
# Epoch 43: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 33s 336ms/step - loss: 0.0332 - accuracy: 0.9862 - val_loss: 0.2598 - val_accuracy: 0.9488
# Epoch 44/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9893
# Epoch 44: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 30s 337ms/step - loss: 0.0294 - accuracy: 0.9893 - val_loss: 0.2189 - val_accuracy: 0.9581
# Epoch 45/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9880
# Epoch 45: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 30s 340ms/step - loss: 0.0277 - accuracy: 0.9880 - val_loss: 0.2135 - val_accuracy: 0.9573
# Epoch 46/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9889
# Epoch 46: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 30s 335ms/step - loss: 0.0270 - accuracy: 0.9889 - val_loss: 0.2160 - val_accuracy: 0.9542
# Epoch 47/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9949
# Epoch 47: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 31s 351ms/step - loss: 0.0147 - accuracy: 0.9949 - val_loss: 0.2561 - val_accuracy: 0.9526
# Epoch 48/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9932
# Epoch 48: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 32s 358ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.2447 - val_accuracy: 0.9612
# Epoch 49/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9924
# Epoch 49: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 32s 360ms/step - loss: 0.0233 - accuracy: 0.9924 - val_loss: 0.2212 - val_accuracy: 0.9604
# Epoch 50/50
# 81/81 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9932
# Epoch 50: val_accuracy did not improve from 0.96506
# 81/81 [==============================] - 36s 372ms/step - loss: 0.0237 - accuracy: 0.9932 - val_loss: 0.2395 - val_accuracy: 0.9557

# %%
# Load the best model
loaded_model = models.load_model('model.h5')

# %%
# Evaluate the model
test_loss, test_acc = loaded_model.evaluate(test_generator)
print(f'Test Accuracy: {test_acc}')
# Out:
# 21/21 [==============================] - 24s 1s/step - loss: 0.1678 - accuracy: 0.9651
# Test Accuracy: 0.965062141418457

# %%
# Plot the training history
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
plt.show()

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# Predict using the loaded model
test_generator.reset()
predictions = loaded_model.predict_generator(test_generator)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = test_generator.classes

# Get class names
class_names = label_mapping

# Plot confusion matrix
plot_confusion_matrix(true_labels, predicted_labels, class_names)
# Out:
# /tmp/ipykernel_59368/3787465623.py:18: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = loaded_model.predict_generator(test_generator)

# %%
# Function to plot confusion matrix with additional metrics
def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')

    # Calculate additional metrics
    accuracy = np.trace(cm) / np.sum(cm)
    precision = np.diagonal(cm) / np.sum(cm, axis=0)
    recall = np.diagonal(cm) / np.sum(cm, axis=1)
    f1_score = 2 * (precision * recall) / (precision + recall)

    print(f"Accuracy: {accuracy:.2f}")
    print(f"Precision: {np.mean(precision):.2f}")
    print(f"Recall: {np.mean(recall):.2f}")
    print(f"F1 Score: {np.mean(f1_score):.2f}")

    plt.show()

# Plot confusion matrix with additional metrics
plot_confusion_matrix(true_labels, predicted_labels, list(class_names.keys()))
# Out:
# Accuracy: 0.97
# Precision: 0.97
# Recall: 0.97
# F1 Score: 0.97

# %%
# Get class names
class_dict = label_mapping
# Convert dictionary values to strings
class_name = np.array(list(class_dict.keys()))

# %%
print(class_name)
# Out:
# ['cocci' 'salmo' 'healthy']
